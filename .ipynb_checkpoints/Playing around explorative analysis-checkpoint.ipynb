# %%
# %run code/import_libs.py
# %run code/functions.py
# %run code/Build_Forms.py
# %run code/initial_data_prep.py

# %matplotlib inline


pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 30)
pd.options.display.float_format = '{:,}'.format

# %%
initial_pred = df.drop(columns=["price"]).copy()
initial_price = df[["price"]]

#FILTER

#df=df[df['yr_built']>1980]
#df=df[df['price']<1000000].copy()
#df=df[df['sqft_living']<12000].copy()
#df=df[df['sqft_lot']<1000000].copy()
df=df[~df["grade"].isin([3,4,5])]

df['view'].unique()
# Out:
# ['NONE', 'GOOD', 'EXCELLENT', 'AVERAGE', 'FAIR']
# Categories (5, object): ['AVERAGE', 'EXCELLENT', 'FAIR', 'GOOD', 'NONE']

# %%
df['zipcode'].value_counts().head()
np.percentile(df['sqft_living'], 49), np.percentile(df['sqft_living'], 51)
df['grade'].median()
# Out:
# 7.0

# %%
avg_sq_df=df[(df['sqft_living'] >= 1850) & (df['sqft_living'] <= 2050)].copy()
avg_grade_df=df[df['grade'].isin([7,8])]
avg_sq_grade_df=avg_sq_df[avg_sq_df['grade'].isin([7,8])]
by_zipcode_df=avg_sq_grade_df.groupby('zipcode').mean().reset_index()[['zipcode','price']].sort_values(by='price', \
                                                                                                       ascending=False)
zipcode_best_df=by_zipcode_df.head()
zipcode_worst_df=by_zipcode_df.tail()

# %%
by_zipcode_df2=df.groupby('zipcode').mean().reset_index()[['zipcode','price']].sort_values(by='price', \
                                                                                                       ascending=False)
by_zipcode_df2
# Out:
#     zipcode                price
# 24    98039          2,161,300.0
# 3     98004 1,338,475.0158227847
# 25    98040 1,194,873.6382978724
# 48    98112 1,096,239.0074349442
# 47    98109    880,077.752293578
# 43    98105   863,228.9432314411
# 5     98006   859,938.5542168674
# 53    98119   849,714.8097826086
# 41    98102   833,584.4466019417
# 4     98005   810,289.6964285715
# 21    98033   803,990.8194444445
# 69    98199   794,408.1142857143
# 38    98075    790,778.656424581
# 37    98074   686,427.3795454545
# 39    98077   682,885.9898989899
# 65    98177   677,724.1929133858
# 29    98053   673,228.0074626865
# 7     98008   645,628.2261484099
# 28    98052   645,410.4467713787
# 54    98122   634,558.1448275862
# 15    98027   623,370.9481481481
# 49    98115   621,243.4406196213
# 50    98116   620,227.4801223242
# 6     98007   617,254.0212765958
# 17    98029    612,642.738317757
# 14    98024   599,203.5064935065
# 59    98144    595,833.853372434
# 42    98103   587,254.3802345059
# 51    98117   581,025.3658088235
# 45    98107   580,220.4886363636
# 36    98072   570,073.5201465201
# 58    98136   554,818.1046511628
# 34    98065   536,648.5719063545
# 22    98034   522,206.8287292818
# 33    98059    495,910.487012987
# 35    98070  494,689.83928571426
# 9     98011   490,377.1076923077
# 10    98014  479,032.49557522126
# 55    98125   470,405.9654320988
# 63    98166  466,405.92430278886
# 16    98028   463,242.3758865248
# 27    98045   443,558.6465116279
# 31    98056   438,298.1260053619
# 8     98010  434,164.42553191487
# 56    98126  427,366.90544412605
# 11    98019   427,148.2021276596
# 62    98155   424,339.3243243243
# 52    98118    420,278.906374502
# 57    98133     387,457.66598778
# 60    98146   369,138.8109090909
# 23    98038   367,547.5836177474
# 46    98108  359,452.12637362635
# 32    98058   355,188.2422222222
# 40    98092  335,177.05730659026
# 44    98106  321,902.96625766874
# 12    98022   319,208.6710526316
# 66    98178  313,153.85992217896
# 26    98042  311,797.58595194086
# 30    98055  309,212.92156862747
# 68    98198    305,383.802919708
# 19    98031   301,447.8888888889
# 18    98030   296,748.5157480315
# 2     98003  294,111.27857142856
# 67    98188  292,057.99242424243
# 13    98023   287,093.8893360161
# 61    98148   285,259.8181818182
# 0     98001   283,455.0934844193
# 20    98032  254,937.64705882352
# 64    98168  246,213.90551181103
# 1     98002  239,088.65240641712

# %%
worst_zipcodes_df=df[df['zipcode'].isin (zipcode_worst_df['zipcode'])]
best_zipcodes_df=df[df['zipcode'].isin (zipcode_best_df['zipcode'])]

# %%
df['price_per_sqft']
# Out:
# id
# 7129300520   188.05
# 6414100192   209.34
# 5631500400   233.77
# 2487200875   308.16
# 1954400510   303.57
#               ...
# 263000018    235.29
# 6600060120   173.16
# 1523300141   394.22
# 291310100     250.0
# 1523300157   318.63
# Name: price_per_sqft, Length: 21324, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(12,6))

sns.boxplot('grade','price', data=avg_sq_df, ax=ax)

ax.get_yaxis().set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

# %%
# %run code/initial_data_prep.py
df=df[df['price']<2000000].copy()
fig, ax = plt.subplots(figsize=(12,6))

sns.barplot('view','price',  data=df, ax=ax)
plt.xticks(rotation=80);
df['view'].value_counts()
# Out:
# NONE         19011
# AVERAGE        895
# GOOD           555
# FAIR           313
# EXCELLENT      165
# Name: view, dtype: int64

# %%
df['sqft_living_bin']=pd.cut(df['sqft_living'], bins=20)
by_size=df.groupby(['sqft_living_bin']).mean()['price_per_sqft'].reset_index().sort_values(by='sqft_living_bin')

fig, ax = plt.subplots(figsize=(12,6))

sns.barplot('sqft_living_bin','price_per_sqft',  data=by_size, ax=ax)
plt.xticks(rotation=80);
#plt.bar(by_size['price'], list(by_size['sqft_living_bin']))

#bins=np.linspace(df['sqft_living'].min(), df['sqft_living'].max(), 10)
#bins

#plt.hist(df.values, bins=bins, edgecolor="k")

# %%
bins=pd.cut(df['sqft_living'], bins=6)
df[['price_per_sqft']].groupby(bins).agg('mean').plot.bar()
# Out:
# <AxesSubplot:xlabel='sqft_living'>

# %%
fig, ax = plt.subplots(figsize=(12,6))

sns.scatterplot('yr_built','price', data=df, ax=ax)
ax.get_yaxis().set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

# %%
# Out:
# <AxesSubplot:>
